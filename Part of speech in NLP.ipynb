# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")

# %%
doc = nlp("Elon flew to mars yesterday.He carried biryani masala with him")
for token in doc:
    print(token,"|",token.pos_,"|",spacy.explain(token.pos_))
# Out:
# Elon | PROPN | proper noun
# flew | VERB | verb
# to | ADP | adposition
# mars | NOUN | noun
# yesterday | NOUN | noun
# . | PUNCT | punctuation
# He | PRON | pronoun
# carried | VERB | verb
# biryani | NOUN | noun
# masala | NOUN | noun
# with | ADP | adposition
# him | PRON | pronoun

# %%
doc=nlp("wow! Dr. Strange made 265 million $ on the very first day")

# %%
for token in doc:
     print(token,"|",token.pos_,"|",spacy.explain(token.pos_),"|",token.tag_,"|",spacy.explain(token.tag_))
# Out:
# wow | INTJ | interjection | UH | interjection
# ! | PUNCT | punctuation | . | punctuation mark, sentence closer
# Dr. | PROPN | proper noun | NNP | noun, proper singular
# Strange | PROPN | proper noun | NNP | noun, proper singular
# made | VERB | verb | VBD | verb, past tense
# 265 | NUM | numeral | CD | cardinal number
# million | NUM | numeral | CD | cardinal number
# $ | PUNCT | punctuation | -RRB- | right round bracket
# on | ADP | adposition | IN | conjunction, subordinating or preposition
# the | DET | determiner | DT | determiner
# very | ADV | adverb | RB | adverb
# first | ADJ | adjective | JJ | adjective (English), other noun-modifier (Chinese)
# day | NOUN | noun | NN | noun, singular or mass

# %%
doc = nlp("he quit the job")
doc[1]
print(doc[1].text,"|",doc[1].tag_,"|",spacy.explain(doc[1].tag_))
# Out:
# quit | VBD | verb, past tense

# %%
earning_text="""Microsoft Corp. today announced the following results for the quarter ended December 31, 2022, as compared to the corresponding period of last fiscal year:

·        Revenue was $52.7 billion and increased 2%  

·        Operating income was $20.4 billion GAAP and $21.6 billion non-GAAP, and decreased 8% and 3%, respectively

·        Net income was $16.4 billion GAAP and $17.4 billion non-GAAP, and decreased 12% and 7%, respectively

·        Diluted earnings per share was $2.20 GAAP and $2.32 non-GAAP, and decreased 11% and 6%, respectively

“The next major wave of computing is being born, as the Microsoft Cloud turns the world’s most advanced AI models into 
a new computing platform,” said Satya Nadella, chairman and chief executive officer of Microsoft. “We are committed to helping 
our customers use our platforms and tools to do more with less today and innovate for the future in the new era of AI.” """

# %%
doc=nlp(earning_text)

# %%
for token in doc:
     print(token,"|",token.pos_,"|",spacy.explain(token.pos_))
# Out:
# Microsoft | PROPN | proper noun
# Corp. | PROPN | proper noun
# today | NOUN | noun
# announced | VERB | verb
# the | DET | determiner
# following | VERB | verb
# results | NOUN | noun
# for | ADP | adposition
# the | DET | determiner
# quarter | NOUN | noun
# ended | VERB | verb
# December | PROPN | proper noun
# 31 | NUM | numeral
# , | PUNCT | punctuation
# 2022 | NUM | numeral
# , | PUNCT | punctuation
# as | SCONJ | subordinating conjunction
# compared | VERB | verb
# to | ADP | adposition
# the | DET | determiner
# corresponding | ADJ | adjective
# period | NOUN | noun
# of | ADP | adposition
# last | ADJ | adjective
# fiscal | ADJ | adjective
# year | NOUN | noun
# : | PUNCT | punctuation
#
#
#  | SPACE | space
# · | PUNCT | punctuation
#         | SPACE | space
# Revenue | NOUN | noun
# was | AUX | auxiliary
# $ | SYM | symbol
# 52.7 | NUM | numeral
# billion | NUM | numeral
# and | CCONJ | coordinating conjunction
# increased | VERB | verb
# 2 | NUM | numeral
# % | NOUN | noun
#
#
#  | SPACE | space
# · | PUNCT | punctuation
#         | SPACE | space
# Operating | VERB | verb
# income | NOUN | noun
# was | AUX | auxiliary
# $ | SYM | symbol
# 20.4 | NUM | numeral
# billion | NUM | numeral
# GAAP | NOUN | noun
# and | CCONJ | coordinating conjunction
# $ | SYM | symbol
# 21.6 | NUM | numeral
# billion | NUM | numeral
# non | NOUN | noun
# - | NOUN | noun
# GAAP | NOUN | noun
# , | PUNCT | punctuation
# and | CCONJ | coordinating conjunction
# decreased | VERB | verb
# 8 | NUM | numeral
# % | NOUN | noun
# and | CCONJ | coordinating conjunction
# 3 | NUM | numeral
# % | NOUN | noun
# , | PUNCT | punctuation
# respectively | ADV | adverb
#
#
#  | SPACE | space
# · | PUNCT | punctuation
#         | SPACE | space
# Net | ADJ | adjective
# income | NOUN | noun
# was | AUX | auxiliary
# $ | SYM | symbol
# 16.4 | NUM | numeral
# billion | NUM | numeral
# GAAP | NOUN | noun
# and | CCONJ | coordinating conjunction
# $ | SYM | symbol
# 17.4 | NUM | numeral
# billion | NUM | numeral
# non | NOUN | noun
# - | NOUN | noun
# GAAP | NOUN | noun
# , | PUNCT | punctuation
# and | CCONJ | coordinating conjunction
# decreased | VERB | verb
# 12 | NUM | numeral
# % | NOUN | noun
# and | CCONJ | coordinating conjunction
# 7 | NUM | numeral
# % | NOUN | noun
# , | PUNCT | punctuation
# respectively | ADV | adverb
#
#
#  | SPACE | space
# · | PUNCT | punctuation
#         | SPACE | space
# Diluted | ADJ | adjective
# earnings | NOUN | noun
# per | ADP | adposition
# share | NOUN | noun
# was | AUX | auxiliary
# $ | SYM | symbol
# 2.20 | NUM | numeral
# GAAP | NOUN | noun
# and | CCONJ | coordinating conjunction
# $ | SYM | symbol
# 2.32 | NUM | numeral
# non | NOUN | noun
# - | NOUN | noun
# GAAP | NOUN | noun
# , | PUNCT | punctuation
# and | CCONJ | coordinating conjunction
# decreased | VERB | verb
# 11 | NUM | numeral
# % | NOUN | noun
# and | CCONJ | coordinating conjunction
# 6 | NUM | numeral
# % | NOUN | noun
# , | PUNCT | punctuation
# respectively | ADV | adverb
#
#
#  | SPACE | space
# “ | PUNCT | punctuation
# The | DET | determiner
# next | ADJ | adjective
# major | ADJ | adjective
# wave | NOUN | noun
# of | ADP | adposition
# computing | NOUN | noun
# is | AUX | auxiliary
# being | AUX | auxiliary
# born | VERB | verb
# , | PUNCT | punctuation
# as | SCONJ | subordinating conjunction
# the | DET | determiner
# Microsoft | PROPN | proper noun
# Cloud | PROPN | proper noun
# turns | VERB | verb
# the | DET | determiner
# world | NOUN | noun
# ’s | PART | particle
# most | ADV | adverb
# advanced | ADJ | adjective
# AI | PROPN | proper noun
# models | NOUN | noun
# into | ADP | adposition
#
#  | SPACE | space
# a | DET | determiner
# new | ADJ | adjective
# computing | NOUN | noun
# platform | NOUN | noun
# , | PUNCT | punctuation
# ” | PUNCT | punctuation
# said | VERB | verb
# Satya | PROPN | proper noun
# Nadella | PROPN | proper noun
# , | PUNCT | punctuation
# chairman | NOUN | noun
# and | CCONJ | coordinating conjunction
# chief | ADJ | adjective
# executive | ADJ | adjective
# officer | NOUN | noun
# of | ADP | adposition
# Microsoft | PROPN | proper noun
# . | PUNCT | punctuation
# “ | PUNCT | punctuation
# We | PRON | pronoun
# are | AUX | auxiliary
# committed | ADJ | adjective
# to | ADP | adposition
# helping | VERB | verb
#
#  | SPACE | space
# our | PRON | pronoun
# customers | NOUN | noun
# use | VERB | verb
# our | PRON | pronoun
# platforms | NOUN | noun
# and | CCONJ | coordinating conjunction
# tools | NOUN | noun
# to | PART | particle
# do | VERB | verb
# more | ADJ | adjective
# with | ADP | adposition
# less | ADJ | adjective
# today | NOUN | noun
# and | CCONJ | coordinating conjunction
# innovate | VERB | verb
# for | ADP | adposition
# the | DET | determiner
# future | NOUN | noun
# in | ADP | adposition
# the | DET | determiner
# new | ADJ | adjective
# era | NOUN | noun
# of | ADP | adposition
# AI | PROPN | proper noun
# . | PUNCT | punctuation
# ” | PUNCT | punctuation

# %%
#removing unncessesary tokens like punctuation space which are not usefull 
filtered_tokens = []
for token in doc:
    if token.pos_ not in ['SPACE','X','PUNCT']:
        filtered_tokens.append(token)

# %%
filtered_tokens
# Out:
# [Microsoft,
#  Corp.,
#  today,
#  announced,
#  the,
#  following,
#  results,
#  for,
#  the,
#  quarter,
#  ended,
#  December,
#  31,
#  2022,
#  as,
#  compared,
#  to,
#  the,
#  corresponding,
#  period,
#  of,
#  last,
#  fiscal,
#  year,
#  Revenue,
#  was,
#  $,
#  52.7,
#  billion,
#  and,
#  increased,
#  2,
#  %,
#  Operating,
#  income,
#  was,
#  $,
#  20.4,
#  billion,
#  GAAP,
#  and,
#  $,
#  21.6,
#  billion,
#  non,
#  -,
#  GAAP,
#  and,
#  decreased,
#  8,
#  %,
#  and,
#  3,
#  %,
#  respectively,
#  Net,
#  income,
#  was,
#  $,
#  16.4,
#  billion,
#  GAAP,
#  and,
#  $,
#  17.4,
#  billion,
#  non,
#  -,
#  GAAP,
#  and,
#  decreased,
#  12,
#  %,
#  and,
#  7,
#  %,
#  respectively,
#  Diluted,
#  earnings,
#  per,
#  share,
#  was,
#  $,
#  2.20,
#  GAAP,
#  and,
#  $,
#  2.32,
#  non,
#  -,
#  GAAP,
#  and,
#  decreased,
#  11,
#  %,
#  and,
#  6,
#  %,
#  respectively,
#  The,
#  next,
#  major,
#  wave,
#  of,
#  computing,
#  is,
#  being,
#  born,
#  as,
#  the,
#  Microsoft,
#  Cloud,
#  turns,
#  the,
#  world,
#  ’s,
#  most,
#  advanced,
#  AI,
#  models,
#  into,
#  a,
#  new,
#  computing,
#  platform,
#  said,
#  Satya,
#  Nadella,
#  chairman,
#  and,
#  chief,
#  executive,
#  officer,
#  of,
#  Microsoft,
#  We,
#  are,
#  committed,
#  to,
#  helping,
#  our,
#  customers,
#  use,
#  our,
#  platforms,
#  and,
#  tools,
#  to,
#  do,
#  more,
#  with,
#  less,
#  today,
#  and,
#  innovate,
#  for,
#  the,
#  future,
#  in,
#  the,
#  new,
#  era,
#  of,
#  AI]

# %%
#count of tags ,pos etc
#count_by used to count pos ,tags , numbers etc
count = doc.count_by(spacy.attrs.POS)
count
# Out:
# {96: 10,
#  92: 43,
#  100: 16,
#  90: 9,
#  85: 12,
#  93: 21,
#  97: 22,
#  98: 2,
#  84: 15,
#  103: 11,
#  87: 7,
#  99: 7,
#  89: 13,
#  86: 4,
#  94: 2,
#  95: 3}

# %%
#making it to alphabatical form
for k,v in count.items():
    print(doc.vocab[k].text,"|",v)
# Out:
# PROPN | 10
# NOUN | 43
# VERB | 16
# DET | 9
# ADP | 12
# NUM | 21
# PUNCT | 22
# SCONJ | 2
# ADJ | 15
# SPACE | 11
# AUX | 7
# SYM | 7
# CCONJ | 13
# ADV | 4
# PART | 2
# PRON | 3
